# %% [markdown]
# # M2 forecast baselines
# Run zero, expanding historical mean, pooled Ridge and XGBoost through the common evaluator.

# %%
import subprocess, sys
RUN_DIR = WORKSPACE / 'runs' / 'v3_forecast_baselines'
subprocess.run([sys.executable, str(REPO / 'scripts' / 'run_v3_forecast_baselines.py'), '--data-root', str(DATA_ROOT), '--run-dir', str(RUN_DIR)], check=True)
import pandas as pd
pd.read_parquet(RUN_DIR / 'forecast_metrics_summary.parquet')
